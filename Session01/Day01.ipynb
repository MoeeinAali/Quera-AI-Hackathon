# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#         font-weight: bolder;
#     }
# </style>
#
# <body>
#     <b><i>
#         <h1>Quera AI Hackathon</h1>
#         <h2>Day 01</h2></i>
#     </b>
#     <hr>
#     <hr>
#
# </body>
#
# </html>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>numpy:</b> matrix - matlab functions.</li>
# <li><b>pandas:</b> data manipulation and analysis + numpy funtions.</li>
# <li><b>matplotlib.pyplot:</b> creating static, animated, and interactive visualizations in data analysis and scientific.</li>
# <li><b>seaborn:</b> specifically designed for creating informative and attractive statistical graphics.</li>
# <li><b>warnings:</b> ignore warnings of some fuctions.</li>
# </ul>
# <hr>
# </body>
#
# </html>

# %%
a = [1, 2, 3]
b = [4, 5, 6]
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = np.array(a)
b = np.array(b)
a + b
# Out:
# array([5, 7, 9])

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <li><b>numpy.array</b> is a Vector!</li>
#
# <hr>
# </body>
#
# </html>

# %%
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
np.cos(b)
# Out:
# array([-0.65364362,  0.28366219,  0.96017029])

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <li>numpy calculate Sin and Cos in radians!</li>
#
# <hr>
# </body>
#
# </html>

# %%
k = np.array([[1, 2, 3], [4, 5, 6]])

# %%
k.shape
# Out:
# (2, 3)

# %%
k.ndim
# Out:
# 2

# %%
k.size
# Out:
# 6

# %%
k.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>array.shape:</b> returns shape of the matrix.</li>
# <li><b>array.ndim:</b> returns the number of dimensions of the matrix.</li>
# <li><b>array.size:</b> returns the number of matrix fields.</li>
# <li><b>array.T:</b> returns the transpose of a matrix.</li>
# </ul>
# <hr>
# </body>
#
# </html>

# %%
np.random.rand()
# Out:
# 0.9591394604403047

# %%
np.random.rand(2, 3)
# Out:
# array([[0.1113759 , 0.63499411, 0.7538654 ],
#        [0.43386953, 0.2166837 , 0.06918379]])

# %%
np.random.randn(5)
# Out:
# array([-0.87479026, -0.70821212,  0.45834278,  1.58003048, -0.56214682])

# %%
np.random.randn(5) * 2 + 3
# Out:
# array([3.05892214, 0.70350368, 3.66296573, 1.95327566, 2.32309118])

# %%
np.linspace(-5, 5, 10)
# Out:
# array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#         0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ])

# %%
a = np.array([1, 2])
b = np.array([3, 4])
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>np.random.rand():</b> generates a random number between 0 and 1.</li>
# <li><b>np.random.rand(p,q):</b> generates a matrix with shape of (p,q) with random fields between 0 and 1.</li>
# <li><b>np.random.rand(k):</b> generates a matrix with shape of (1,k) with random fields between 0 and 1.</li>
# <li><b>np.random.randn(p,q):</b> generates a matrix with shape of (p,q) with random fields between 0 and 1 with Normal distribution.</li>
# <li><b>np.random.randn(k):</b> generates a matrix with shape of (1,k) with random fields between 0 and 1 with Normal distribution.</li>
# <li><b>np.random.linspace(p,q,n):</b> generates a matrix with shape of (1,n) with Average of (p+q)/2.</li>
# <li><b>np.concatenate(a,b):</b> connects two np.array to each other.</li>
# </ul>
#
# <hr>
# </body>
#
# </html>

# %%
x = [1, 3, 5]
y = [3, -2, 5]
plt.plot(x, y)
plt.xlabel('width')
plt.ylabel('height')
plt.show()

# %%
from math import pi

x = [0, pi / 2, pi, 3 * pi / 2, 2 * pi]
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 2 * pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
data = np.random.randn(10000)
plt.hist(data, bins=100)
plt.show()

# %%
data[(data > -1) & (data < 0)]
# Out:
# array([-0.16715934, -0.57131528, -0.30026121, ..., -0.96138777,
#        -0.91574755, -0.3598527 ])

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>plt.plot(x,y):</b> draws the diagram.</li>
# <li><b>plt.xlabel("String"):</b> set the label of X axis.</li>
# <li><b>plt.ylabel("String"):</b> set the label of Y axis.</li>
# <li><b>plt.show():</b> shows the diagram.</li>
# <li><b>plt.hist(data, bins=100):</b> shows the histogram of datas with `bins` columns.</li>
# </ul>
#
# <hr>
# </body>
#
# </html>

# %%
df = pd.DataFrame({
    'Name': ['Moeein', 'Soheil', 'Mohsen'],
    'Age': [20, 30, 100]
})
df
# Out:
#      Name  Age
# 0  Moeein   20
# 1  Soheil   30
# 2  Mohsen  100

# %%
df = pd.read_csv('titanic/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
plt.hist(df.Age)
plt.show()

# %%
df[df.Age < 10]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>df = pd.DataFrame({
#     'Column1': ['Moeein', 'Soheil', 'Mohsen'],
#     'Column2': [20, 30, 100]
# }):</b> make a dataframe.</li>
# <li><b>df = pd.read_csv('url'):</b> read dataframe from a CSV file.</li>
# <li><b>df.columns:</b> show the columns of a CSV file.</li>
# <li><b>df.info():</b> show some information about a CSV file.</li>
# <li><b>df.describe():</b> show some numeric statistical information about a CSV file.</li>
# <li><b>df.describe(include='all'):</b> show all statistical information about a CSV file.</li>
# <li><b>df.head(n):</b> show `n` first lines of a CSV file.</li>
# <li><b>df.tail(n):</b> show `n` last lines of a CSV file.</li>
# </ul>
#
# <hr>
# </body>
#
# </html>

# %%
df = pd.DataFrame({'x': [1, 2, 1, 2], 'y': [1, 1, 2, 2]})
df
# Out:
#    x  y
# 0  1  1
# 1  2  1
# 2  1  2
# 3  2  2

# %%
plt.scatter(df.x, df.y)

# %%
from sklearn.cluster import KMeans

# %%
k = KMeans(n_clusters=2)
k.fit(df)
# Out:
# KMeans(n_clusters=2)

# %%
k.labels_
# Out:
# array([0, 1, 0, 1])

# %%
k.inertia_
# Out:
# 1.0

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>plt.scatter(x, y):</b> draw the graph as points.</li>
# <li><b>sklearn.cluster:</b> this is a library for clustering methods and comparison.</li>
# <li><b>KMeans:</b> k-means clustering is a method of vector quantization.</li>
# <li><b>k = KMeans(n_clusters=`n`):</b> make an empty object from KMeans with `n` clusters.</li>
# <li><b>k.fit(`DataFrame`):</b> run KMeans method on `DataFrame` with `k` object.</li>
# <li><b>k.labels_:</b> it shows how our data is clustered.</li>
# <li><b>k.inertia_:</b> it measures how well a dataset was clustered by KMeans.</li>
# <br>
# <li style="list-style: square;">a good model is one with<b> low inertia</b> and a <b>low number of clusters </b>.</li>
#
# </ul>
#
# <hr>
# </body>
#
# </html>

# %%
def plot_Kmeans(df: pd.DataFrame, cnt: int):
    x = df['x'].values
    y = df['y'].values
    rows = 2
    cols = 5
    fig, axes = plt.subplots(rows, cols, figsize=(20, 10))

    for i in range(1, cnt+1):
        k = KMeans(n_clusters=i)
        k.fit(np.array(list(zip(x, y))))
        centers = k.cluster_centers_

        row = (i-1) // cols
        col = (i-1) % cols

        ax = axes[row, col]
        ax.scatter(df.x, df.y, c=k.labels_)
        centers_df = pd.DataFrame(centers, columns=['x', 'y'])
        ax.scatter(centers_df.x, centers_df.y, c='red', marker='x')
        ax.set_title(f'KMeans with {i} clusters\nwith inertia:{k.inertia_}')

    plt.tight_layout()
    plt.show()

# %%
a = np.random.rand(1000)
b = np.random.rand(1000) + 1.1

# %%
x = np.concatenate((a, a, b, b))
y = np.concatenate((a, b, a, b))
df = pd.DataFrame({'x': x, 'y': y})
plot_Kmeans(df=df, cnt=10)

# %%
x = np.concatenate((a, b))
y = np.concatenate((b, a))
df = pd.DataFrame({'x': x, 'y': y})
plot_Kmeans(df=df, cnt=10)

# %%
def plot_inertia(df:pd.DataFrame , cnt:int)
    cnt = 2 # Count of Clusters
    elbow = []
    for i in range(1, cnt+1):
        k = KMeans(n_clusters=i)
        k.fit(df)
        elbow.append(k.inertia_)

    plt.plot(range(1, cnt+1), elbow, marker='o')
    plt.xticks(range(1, cnt+1))
    plt.show()

# %%
()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li>at the <b>breaking point</b> of the graph, we have a better approximation. </li>
# <br>
#
# </ul>
#
# <hr>
# </body>
#
# </html>

# %%
a = np.random.rand(1000)
b = np.random.rand(1000)
x = a
y = b
df = pd.DataFrame({'x': x, 'y': y})
k = KMeans(n_clusters=4)
k.fit(df)
plt.scatter(df.x, df.y, c=k.labels_)
plt.show()

# %%
a = np.random.rand(1000)
b = np.random.rand(1000)
x = np.concatenate((a, a, b, b, np.array([7])))
y = np.concatenate((a, b, a, b, np.array([0.8])))
df = pd.DataFrame({'x': x, 'y': y})
k = KMeans(n_clusters=4)
k.fit(df)
plt.scatter(df.x, df.y, c=k.labels_)
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <ul>
# <li><b>State 1:</b> without a outliere. </li>
# <li><b>State 2:</b> with a outliere. </li>
# <br>
# </ul>
# <hr>
# </body>
#
# </html>

# %%
# without Scaling

a = [1, 1, 1, 1, 1, 1, 2, 2, 2, 2]
b = [
    110000, 111000, 112000, 200000, 202000, 198000, 110000, 111000, 112000,
    115500
]
features = pd.DataFrame({'x': a, 'y': b})
plt.scatter(features.x, features.y)
plt.xlim(0, 220000)
plt.ylim(0, 220000)
plt.show()

# %%
# With Scaling - without library

a = [1, 1, 1, 1, 1, 1, 2, 2, 2, 2]
b = [
    110000, 111000, 112000, 200000, 202000, 198000, 110000, 111000, 112000,
    115500
]
features = pd.DataFrame({'x': a, 'y': b})
features.x = (features.x - features.x.min()) / \
    (features.x.max() - features.x.min())
features.y = (features.y - features.y.min()) / \
    (features.y.max() - features.y.min())
plt.scatter(features.x, features.y)
plt.show()

# %%
# With Scaling - with library

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
a = [1, 1, 1, 1, 1, 1, 2, 2, 2, 2]
b = [
    110000, 111000, 112000, 200000, 202000, 198000, 110000, 111000, 112000,
    115500
]
features = pd.DataFrame({'x': a, 'y': b})
features = pd.DataFrame(sc.fit_transform(features), columns=features.columns)
plt.scatter(features.x, features.y)
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
# </head>
# <style>
#     * {
#         font-family: 'Times New Roman', Times, serif;
#     }
# </style>
#
# <body>
# <h4>we have 2 methods for scaling datas :</h4>
# <ul>
# <li><b>method 1:</b> Normalization </li>
# <li><b>method 2:</b> Standardization </li>
# <br>
# </ul>
# <img src="./pic/pic1.png" style="width: 350px;border: 1px solid black;">
#
# <hr>
# </body>
#
# </html>
